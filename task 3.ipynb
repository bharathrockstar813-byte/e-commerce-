# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathrockstar813-byte/e-commerce-/blob/main/task%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
# load datset
df=sns.load_dataset("tips")
#diplay first 5 row
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df["total_bill"].sum())
# Out:
# 4827.77

# %%
print(df["total_bill"].mean())
# Out:
# 19.78594262295082

# %%
print(df["total_bill"].max())
# Out:
# 50.81

# %%
print(df["total_bill"].min())
# Out:
# 3.07

# %%
print(df["total_bill"].count())
# Out:
# 244

# %%
print(df["total_bill"].median())
# Out:
# 17.795

# %%
print(df["total_bill"].std())
# Out:
# 8.902411954856856

# %%
print(df["total_bill"].var())
# Out:
# 79.25293861397826

# %%
from numpy import maximum
print(df["total_bill"].describe())
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
print(df["total_bill"].agg(['sum', 'mean', 'max', 'min', 'count', 'std', 'var']))
# Out:
# sum      4827.770000
# mean       19.785943
# max        50.810000
# min         3.070000
# count     244.000000
# std         8.902412
# var        79.252939
# Name: total_bill, dtype: float64
