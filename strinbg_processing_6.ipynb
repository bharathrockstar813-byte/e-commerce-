# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathrockstar813-byte/e-commerce-/blob/main/strinbg_processing_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/data cleaing/string_processing_dataset (1).csv")

# %%
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      RAJU@YAHOO.COM   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      Guntur          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["email"]=df["email"].str.lower() # we are covintering intpo lower case
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      raju@yahoo.com   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      Guntur          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      raju@yahoo.com   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# ...

# %%
df["city"]=df["city"].str.upper() # we are covintering intpo upper case
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA         Rs 1000
# 1           RAJU KUMAR      RAJU@YAHOO.COM   HYDERABAD            $250
# 2          kiran reddy     KIRAN@GMAIL.COM      VIZAG         Rs 3,500
# 3        SURESH BABU    SURESH@OUTLOOK.COM      GUNTUR          $1,200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["customer_name"]=df["customer_name"].str.title() # we are covintering intpo lower case
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA         Rs 1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD            $250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG         Rs 3,500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR          $1,200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["name_lenth"]=df["customer_name"].str.len() # we are covintering intpo lower case
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA         Rs 1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD            $250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG         Rs 3,500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR          $1,200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI          Rs 750
#
#         phone product_code    join_date  name_lenth
# 0  9876543210      PRD-101  12-Jan-2024          19
# 1  9123456789      PRD-202  05-Feb-2024          10
# 2  9988776655      PRD-303  18-Mar-2024          13
# 3  9871234567      PRD-404  22-Apr-2024          13
# 4  9012345678      PRD-505  30-May-2024          12

# %%
#regex=flazse tella a pandas to treat the value as noraml text and not as aspecial pattrn

# %%
df["purchase_amount"]=df["purchase_amount"].str.replace("$","",regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG            3,500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR           1,200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth
# 0  9876543210      PRD-101  12-Jan-2024          19
# 1  9123456789      PRD-202  05-Feb-2024          10
# 2  9988776655      PRD-303  18-Mar-2024          13
# 3  9871234567      PRD-404  22-Apr-2024          13
# 4  9012345678      PRD-505  30-May-2024          12

# %%
df["purchase_amount"]=df["purchase_amount"].str.replace("Rs","",regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG            3,500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR           1,200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth
# 0  9876543210      PRD-101  12-Jan-2024          19
# 1  9123456789      PRD-202  05-Feb-2024          10
# 2  9988776655      PRD-303  18-Mar-2024          13
# 3  9871234567      PRD-404  22-Apr-2024          13
# 4  9012345678      PRD-505  30-May-2024          12

# %%
df["purchase_amount"]=df["purchase_amount"].str.replace(",","",regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth
# 0  9876543210      PRD-101  12-Jan-2024          19
# 1  9123456789      PRD-202  05-Feb-2024          10
# 2  9988776655      PRD-303  18-Mar-2024          13
# 3  9871234567      PRD-404  22-Apr-2024          13
# 4  9012345678      PRD-505  30-May-2024          12

# %%
df["is_mail"]=df["email"].str.contains("gmail")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail
# 0  9876543210      PRD-101  12-Jan-2024          19    False
# 1  9123456789      PRD-202  05-Feb-2024          10    False
# 2  9988776655      PRD-303  18-Mar-2024          13    False
# 3  9871234567      PRD-404  22-Apr-2024          13    False
# 4  9012345678      PRD-505  30-May-2024          12    False

# %%
df["startswithv"]=df["city"].str.startswith("v")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv
# 0  9876543210      PRD-101  12-Jan-2024          19    False        False
# 1  9123456789      PRD-202  05-Feb-2024          10    False        False
# 2  9988776655      PRD-303  18-Mar-2024          13    False        False
# 3  9871234567      PRD-404  22-Apr-2024          13    False        False
# 4  9012345678      PRD-505  30-May-2024          12    False        False

# %%
df["email_parts"]=df["email"].str.split("@")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210      PRD-101  12-Jan-2024          19    False        False
# 1  9123456789      PRD-202  05-Feb-2024          10    False        False
# 2  9988776655      PRD-303  18-Mar-2024          13    False        False
# 3  9871234567      PRD-404  22-Apr-2024          13    False        False
# 4  9012345678      PRD-505  30-May-2024          12    False        False
#
#              email_parts
# 0  [SANTHOSH, GMAIL.COM]
# 1      [RAJU, YAHOO.COM]
# ...

# %%
df["username"]=df["email"].str.split("@").str[0]
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210      PRD-101  12-Jan-2024          19    False        False
# 1  9123456789      PRD-202  05-Feb-2024          10    False        False
# 2  9988776655      PRD-303  18-Mar-2024          13    False        False
# 3  9871234567      PRD-404  22-Apr-2024          13    False        False
# 4  9012345678      PRD-505  30-May-2024          12    False        False
#
#              email_parts  username
# 0  [SANTHOSH, GMAIL.COM]  SANTHOSH
# ...

# %%
df["city_code"]=df["city"].str[:3]
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210      PRD-101  12-Jan-2024          19    False        False
# 1  9123456789      PRD-202  05-Feb-2024          10    False        False
# 2  9988776655      PRD-303  18-Mar-2024          13    False        False
# 3  9871234567      PRD-404  22-Apr-2024          13    False        False
# 4  9012345678      PRD-505  30-May-2024          12    False        False
#
#              email_parts  username city_code
# 0  [SANTHOSH, GMAIL.COM]  SANTHOSH       VIJ
# ...

# %%
df["is_numeric"]=df["phone"].astype(str).str.isnumeric()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210      PRD-101  12-Jan-2024          19    False        False
# 1  9123456789      PRD-202  05-Feb-2024          10    False        False
# 2  9988776655      PRD-303  18-Mar-2024          13    False        False
# 3  9871234567      PRD-404  22-Apr-2024          13    False        False
# 4  9012345678      PRD-505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric
# ...

# %%
df["product_code"]=df["product_code"].str.removeprefix("PRD-")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric
# ...

# %%
df["product_code"]=df["product_code"].str.removesuffix("PRD--")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric
# ...

# %%
#task 5

# %%
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric
# ...

# %%
df["name"]=df["customer_name"].str.title()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   SANTHOSH@GMAIL.COM  VIJAYAWADA            1000
# 1           Raju Kumar      RAJU@YAHOO.COM   HYDERABAD             250
# 2          Kiran Reddy     KIRAN@GMAIL.COM      VIZAG             3500
# 3        Suresh Babu    SURESH@OUTLOOK.COM      GUNTUR            1200
# 4         Lakshmi Devi   LAKSHMI@GMAIL.COM    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name
# ...

# %%
df["email"]=df["email"].str.lower()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name
# ...

# %%
df["name"]=df["customer_name"].str.upper()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name
# ...

# %%
df["account"]=df["purchase_amount"].str.upper()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name  \
# ...

# %%
df["removing"]=df["purchase_amount"].str.replace("Rs","",regex=False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name  \
# ...

# %%
df["is_numeric"]=df["phone"].astype(str).str.isnumeric()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name  \
# ...

# %%
df["username"]=df["email"].str.contains("gmail")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name  \
# ...

# %%
df["city_code"]=df["city"].str[:3]
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name  \
# ...

# %%
df["product_code"]=df["product_code"].str.removeprefix("PRD-")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_lenth  is_mail  startswithv  \
# 0  9876543210          101  12-Jan-2024          19    False        False
# 1  9123456789          202  05-Feb-2024          10    False        False
# 2  9988776655          303  18-Mar-2024          13    False        False
# 3  9871234567          404  22-Apr-2024          13    False        False
# 4  9012345678          505  30-May-2024          12    False        False
#
#              email_parts  username city_code  is_numeric                 name  \
# ...
